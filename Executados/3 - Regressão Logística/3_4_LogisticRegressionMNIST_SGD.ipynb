# %% [markdown]
# # Regressão Softmax com dados do MNIST utilizando gradiente descendente estocástico por minibatches

# %% [markdown]
# O objetivo deste notebook é ilustrar
# - o uso do gradiente estocástico por mini-batchs
# - utilizando as classes Dataset e DataLoater.
#
# A apresentação da perda nos gráficos é um pouco diferente da usual, mostrando a perda de cada um dos vários minibatches dentro de cada época, de forma que as épocas são apresentadas com valores fracionários.

# %% [markdown]
# ## Importação das bibliotecas

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader

import torchvision
from torchvision.datasets import MNIST

# %% [markdown]
# ## Dataset e dataloader

# %% [markdown]
# ### Definição do tamanho do minibatch

# %%
batch_size = 100

# %% [markdown]
# ### Carregamento, criação dataset e do dataloader

# %%
! git clone https://github.com/vcasadei/MNIST.git
# Out:
# Cloning into 'MNIST'...
# remote: Enumerating objects: 10, done.
# remote: Total 10 (delta 0), reused 0 (delta 0), pack-reused 10
# Unpacking objects: 100% (10/10), done.

# %%
dataset_dir = 'MNIST/'

dataset_train = MNIST(dataset_dir, train=True, download=True,
                      transform=torchvision.transforms.ToTensor())

loader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

print('Número de minibatches de trenamento:', len(loader_train))

x_train, y_train = next(iter(loader_train))
print("\nDimensões dos dados de um minibatch:", x_train.size())
print("Valores mínimo e máximo dos pixels: ", torch.min(x_train), torch.max(x_train))
print("Tipo dos dados das imagens:         ", type(x_train))
print("Tipo das classes das imagens:       ", type(y_train))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to MNIST/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting MNIST/MNIST/raw/train-images-idx3-ubyte.gz to MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to MNIST/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting MNIST/MNIST/raw/train-labels-idx1-ubyte.gz to MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz to MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz to MNIST/MNIST/raw
#
# Número de minibatches de trenamento: 600
#
# Dimensões dos dados de um minibatch: torch.Size([100, 1, 28, 28])
# Valores mínimo e máximo dos pixels:  tensor(0.) tensor(1.)
# Tipo dos dados das imagens:          <class 'torch.Tensor'>
# Tipo das classes das imagens:        <class 'torch.Tensor'>

# %% [markdown]
# ### Usando apenas 1000 amostras do MNIST
#
# Neste exemplo utilizaremos 1000 amostras de treinamento.

# %%
if False:
    n_samples_train = 1000

    dataset_train.train_data = dataset_train.train_data[:n_samples_train]
    dataset_train.train_labels = dataset_train.train_labels[:n_samples_train]

print('Número de minibatches de trenamento:', len(loader_train))
n_batches_train = len(loader_train)
total_samples = dataset_train.train_data.size(0)
# Out:
# Número de minibatches de trenamento: 600
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:75: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")

# %% [markdown]
# ## Modelo

# %%
model = torch.nn.Linear(28*28, 10)

# %%
x = torch.ones(28*28).reshape(1, 784)
print(x.shape)
predict = model(x)
predict
# Out:
# torch.Size([1, 784])
# tensor([[-0.0840,  0.3103, -0.4379, -0.5808,  0.0770,  0.1189, -0.6192,  0.1211,
#           0.3895,  0.2262]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## Treinamento

# %% [markdown]
# ### Inicialização dos parâmetros

# %%
n_epochs = 2
learningRate = 0.5

# Utilizaremos CrossEntropyLoss como função de perda
criterion = torch.nn.CrossEntropyLoss()

# Gradiente descendente
optimizer = torch.optim.SGD(model.parameters(), lr=learningRate)

# %% [markdown]
# ### Laço de treinamento dos parâmetros

# %%
epochs = []
losses = []

total_trained_samples = 0
for i in range(n_epochs):
    for k,(x_train, y_train) in enumerate(loader_train):
        # Transforma a entrada para uma dimensão
        inputs = Variable(x_train.view(-1, 28 * 28))
        # predict da rede
        outputs = model(inputs)

        # calcula a perda
        loss = criterion(outputs, Variable(y_train))

        # zero, backpropagation, ajusta parâmetros pelo gradiente descendente
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_trained_samples += x_train.size(0)
        epochs.append(total_trained_samples / total_samples)
        losses.append(loss.data)
        # print(k)
        print(f'Época: {i}/{n_epochs-1} minibatch: {k + 1}/{len(loader_train)}')#.format(i,n_epochs-1))#, end='\r')
# Out:
# Época: 0/1 minibatch: 1/600
# Época: 0/1 minibatch: 2/600
# Época: 0/1 minibatch: 3/600
# Época: 0/1 minibatch: 4/600
# Época: 0/1 minibatch: 5/600
# Época: 0/1 minibatch: 6/600
# Época: 0/1 minibatch: 7/600
# Época: 0/1 minibatch: 8/600
# Época: 0/1 minibatch: 9/600
# Época: 0/1 minibatch: 10/600
# Época: 0/1 minibatch: 11/600
# Época: 0/1 minibatch: 12/600
# Época: 0/1 minibatch: 13/600
# Época: 0/1 minibatch: 14/600
# Época: 0/1 minibatch: 15/600
# Época: 0/1 minibatch: 16/600
# Época: 0/1 minibatch: 17/600
# Época: 0/1 minibatch: 18/600
# Época: 0/1 minibatch: 19/600
# Época: 0/1 minibatch: 20/600
# Época: 0/1 minibatch: 21/600
# Época: 0/1 minibatch: 22/600
# Época: 0/1 minibatch: 23/600
# Época: 0/1 minibatch: 24/600
# Época: 0/1 minibatch: 25/600
# Época: 0/1 minibatch: 26/600
# Época: 0/1 minibatch: 27/600
# Época: 0/1 minibatch: 28/600
# Época: 0/1 minibatch: 29/600
# Época: 0/1 minibatch: 30/600
# Época: 0/1 minibatch: 31/600
# Época: 0/1 minibatch: 32/600
# Época: 0/1 minibatch: 33/600
# Época: 0/1 minibatch: 34/600
# Época: 0/1 minibatch: 35/600
# Época: 0/1 minibatch: 36/600
# Época: 0/1 minibatch: 37/600
# Época: 0/1 minibatch: 38/600
# Época: 0/1 minibatch: 39/600
# Época: 0/1 minibatch: 40/600
# Época: 0/1 minibatch: 41/600
# Época: 0/1 minibatch: 42/600
# Época: 0/1 minibatch: 43/600
# Época: 0/1 minibatch: 44/600
# Época: 0/1 minibatch: 45/600
# Época: 0/1 minibatch: 46/600
# Época: 0/1 minibatch: 47/600
# Época: 0/1 minibatch: 48/600
# Época: 0/1 minibatch: 49/600
# Época: 0/1 minibatch: 50/600
# Época: 0/1 minibatch: 51/600
# Época: 0/1 minibatch: 52/600
# Época: 0/1 minibatch: 53/600
# Época: 0/1 minibatch: 54/600
# Época: 0/1 minibatch: 55/600
# Época: 0/1 minibatch: 56/600
# Época: 0/1 minibatch: 57/600
# Época: 0/1 minibatch: 58/600
# Época: 0/1 minibatch: 59/600
# Época: 0/1 minibatch: 60/600
# Época: 0/1 minibatch: 61/600
# Época: 0/1 minibatch: 62/600
# Época: 0/1 minibatch: 63/600
# Época: 0/1 minibatch: 64/600
# Época: 0/1 minibatch: 65/600
# Época: 0/1 minibatch: 66/600
# Época: 0/1 minibatch: 67/600
# Época: 0/1 minibatch: 68/600
# Época: 0/1 minibatch: 69/600
# Época: 0/1 minibatch: 70/600
# Época: 0/1 minibatch: 71/600
# Época: 0/1 minibatch: 72/600
# Época: 0/1 minibatch: 73/600
# Época: 0/1 minibatch: 74/600
# Época: 0/1 minibatch: 75/600
# Época: 0/1 minibatch: 76/600
# Época: 0/1 minibatch: 77/600
# Época: 0/1 minibatch: 78/600
# Época: 0/1 minibatch: 79/600
# Época: 0/1 minibatch: 80/600
# Época: 0/1 minibatch: 81/600
# Época: 0/1 minibatch: 82/600
# Época: 0/1 minibatch: 83/600
# Época: 0/1 minibatch: 84/600
# Época: 0/1 minibatch: 85/600
# Época: 0/1 minibatch: 86/600
# Época: 0/1 minibatch: 87/600
# Época: 0/1 minibatch: 88/600
# Época: 0/1 minibatch: 89/600
# Época: 0/1 minibatch: 90/600
# Época: 0/1 minibatch: 91/600
# Época: 0/1 minibatch: 92/600
# Época: 0/1 minibatch: 93/600
# Época: 0/1 minibatch: 94/600
# Época: 0/1 minibatch: 95/600
# Época: 0/1 minibatch: 96/600
# Época: 0/1 minibatch: 97/600
# Época: 0/1 minibatch: 98/600
# Época: 0/1 minibatch: 99/600
# Época: 0/1 minibatch: 100/600
# Época: 0/1 minibatch: 101/600
# Época: 0/1 minibatch: 102/600
# Época: 0/1 minibatch: 103/600
# Época: 0/1 minibatch: 104/600
# Época: 0/1 minibatch: 105/600
# Época: 0/1 minibatch: 106/600
# Época: 0/1 minibatch: 107/600
# Época: 0/1 minibatch: 108/600
# Época: 0/1 minibatch: 109/600
# Época: 0/1 minibatch: 110/600
# Época: 0/1 minibatch: 111/600
# Época: 0/1 minibatch: 112/600
# Época: 0/1 minibatch: 113/600
# Época: 0/1 minibatch: 114/600
# Época: 0/1 minibatch: 115/600
# Época: 0/1 minibatch: 116/600
# Época: 0/1 minibatch: 117/600
# Época: 0/1 minibatch: 118/600
# Época: 0/1 minibatch: 119/600
# Época: 0/1 minibatch: 120/600
# Época: 0/1 minibatch: 121/600
# Época: 0/1 minibatch: 122/600
# Época: 0/1 minibatch: 123/600
# Época: 0/1 minibatch: 124/600
# Época: 0/1 minibatch: 125/600
# Época: 0/1 minibatch: 126/600
# Época: 0/1 minibatch: 127/600
# Época: 0/1 minibatch: 128/600
# Época: 0/1 minibatch: 129/600
# Época: 0/1 minibatch: 130/600
# Época: 0/1 minibatch: 131/600
# Época: 0/1 minibatch: 132/600
# Época: 0/1 minibatch: 133/600
# Época: 0/1 minibatch: 134/600
# Época: 0/1 minibatch: 135/600
# Época: 0/1 minibatch: 136/600
# Época: 0/1 minibatch: 137/600
# Época: 0/1 minibatch: 138/600
# Época: 0/1 minibatch: 139/600
# Época: 0/1 minibatch: 140/600
# Época: 0/1 minibatch: 141/600
# Época: 0/1 minibatch: 142/600
# Época: 0/1 minibatch: 143/600
# Época: 0/1 minibatch: 144/600
# Época: 0/1 minibatch: 145/600
# Época: 0/1 minibatch: 146/600
# Época: 0/1 minibatch: 147/600
# Época: 0/1 minibatch: 148/600
# Época: 0/1 minibatch: 149/600
# Época: 0/1 minibatch: 150/600
# Época: 0/1 minibatch: 151/600
# Época: 0/1 minibatch: 152/600
# Época: 0/1 minibatch: 153/600
# Época: 0/1 minibatch: 154/600
# Época: 0/1 minibatch: 155/600
# Época: 0/1 minibatch: 156/600
# Época: 0/1 minibatch: 157/600
# Época: 0/1 minibatch: 158/600
# Época: 0/1 minibatch: 159/600
# Época: 0/1 minibatch: 160/600
# Época: 0/1 minibatch: 161/600
# Época: 0/1 minibatch: 162/600
# Época: 0/1 minibatch: 163/600
# Época: 0/1 minibatch: 164/600
# Época: 0/1 minibatch: 165/600
# Época: 0/1 minibatch: 166/600
# Época: 0/1 minibatch: 167/600
# Época: 0/1 minibatch: 168/600
# Época: 0/1 minibatch: 169/600
# Época: 0/1 minibatch: 170/600
# Época: 0/1 minibatch: 171/600
# Época: 0/1 minibatch: 172/600
# Época: 0/1 minibatch: 173/600
# Época: 0/1 minibatch: 174/600
# Época: 0/1 minibatch: 175/600
# Época: 0/1 minibatch: 176/600
# Época: 0/1 minibatch: 177/600
# Época: 0/1 minibatch: 178/600
# Época: 0/1 minibatch: 179/600
# Época: 0/1 minibatch: 180/600
# Época: 0/1 minibatch: 181/600
# Época: 0/1 minibatch: 182/600
# Época: 0/1 minibatch: 183/600
# Época: 0/1 minibatch: 184/600
# Época: 0/1 minibatch: 185/600
# Época: 0/1 minibatch: 186/600
# Época: 0/1 minibatch: 187/600
# Época: 0/1 minibatch: 188/600
# Época: 0/1 minibatch: 189/600
# Época: 0/1 minibatch: 190/600
# Época: 0/1 minibatch: 191/600
# Época: 0/1 minibatch: 192/600
# Época: 0/1 minibatch: 193/600
# Época: 0/1 minibatch: 194/600
# Época: 0/1 minibatch: 195/600
# Época: 0/1 minibatch: 196/600
# Época: 0/1 minibatch: 197/600
# Época: 0/1 minibatch: 198/600
# Época: 0/1 minibatch: 199/600
# Época: 0/1 minibatch: 200/600
# Época: 0/1 minibatch: 201/600
# Época: 0/1 minibatch: 202/600
# Época: 0/1 minibatch: 203/600
# Época: 0/1 minibatch: 204/600
# Época: 0/1 minibatch: 205/600
# Época: 0/1 minibatch: 206/600
# Época: 0/1 minibatch: 207/600
# Época: 0/1 minibatch: 208/600
# Época: 0/1 minibatch: 209/600
# Época: 0/1 minibatch: 210/600
# Época: 0/1 minibatch: 211/600
# Época: 0/1 minibatch: 212/600
# Época: 0/1 minibatch: 213/600
# Época: 0/1 minibatch: 214/600
# Época: 0/1 minibatch: 215/600
# Época: 0/1 minibatch: 216/600
# Época: 0/1 minibatch: 217/600
# Época: 0/1 minibatch: 218/600
# Época: 0/1 minibatch: 219/600
# Época: 0/1 minibatch: 220/600
# Época: 0/1 minibatch: 221/600
# Época: 0/1 minibatch: 222/600
# Época: 0/1 minibatch: 223/600
# Época: 0/1 minibatch: 224/600
# Época: 0/1 minibatch: 225/600
# Época: 0/1 minibatch: 226/600
# Época: 0/1 minibatch: 227/600
# Época: 0/1 minibatch: 228/600
# Época: 0/1 minibatch: 229/600
# Época: 0/1 minibatch: 230/600
# Época: 0/1 minibatch: 231/600
# Época: 0/1 minibatch: 232/600
# Época: 0/1 minibatch: 233/600
# Época: 0/1 minibatch: 234/600
# Época: 0/1 minibatch: 235/600
# Época: 0/1 minibatch: 236/600
# Época: 0/1 minibatch: 237/600
# Época: 0/1 minibatch: 238/600
# Época: 0/1 minibatch: 239/600
# Época: 0/1 minibatch: 240/600
# Época: 0/1 minibatch: 241/600
# Época: 0/1 minibatch: 242/600
# Época: 0/1 minibatch: 243/600
# Época: 0/1 minibatch: 244/600
# Época: 0/1 minibatch: 245/600
# Época: 0/1 minibatch: 246/600
# Época: 0/1 minibatch: 247/600
# Época: 0/1 minibatch: 248/600
# Época: 0/1 minibatch: 249/600
# Época: 0/1 minibatch: 250/600
# Época: 0/1 minibatch: 251/600
# Época: 0/1 minibatch: 252/600
# Época: 0/1 minibatch: 253/600
# Época: 0/1 minibatch: 254/600
# Época: 0/1 minibatch: 255/600
# Época: 0/1 minibatch: 256/600
# Época: 0/1 minibatch: 257/600
# Época: 0/1 minibatch: 258/600
# Época: 0/1 minibatch: 259/600
# Época: 0/1 minibatch: 260/600
# Época: 0/1 minibatch: 261/600
# Época: 0/1 minibatch: 262/600
# Época: 0/1 minibatch: 263/600
# Época: 0/1 minibatch: 264/600
# Época: 0/1 minibatch: 265/600
# Época: 0/1 minibatch: 266/600
# Época: 0/1 minibatch: 267/600
# Época: 0/1 minibatch: 268/600
# Época: 0/1 minibatch: 269/600
# Época: 0/1 minibatch: 270/600
# Época: 0/1 minibatch: 271/600
# Época: 0/1 minibatch: 272/600
# Época: 0/1 minibatch: 273/600
# Época: 0/1 minibatch: 274/600
# Época: 0/1 minibatch: 275/600
# Época: 0/1 minibatch: 276/600
# Época: 0/1 minibatch: 277/600
# Época: 0/1 minibatch: 278/600
# Época: 0/1 minibatch: 279/600
# Época: 0/1 minibatch: 280/600
# Época: 0/1 minibatch: 281/600
# Época: 0/1 minibatch: 282/600
# Época: 0/1 minibatch: 283/600
# Época: 0/1 minibatch: 284/600
# Época: 0/1 minibatch: 285/600
# Época: 0/1 minibatch: 286/600
# Época: 0/1 minibatch: 287/600
# Época: 0/1 minibatch: 288/600
# Época: 0/1 minibatch: 289/600
# Época: 0/1 minibatch: 290/600
# Época: 0/1 minibatch: 291/600
# Época: 0/1 minibatch: 292/600
# Época: 0/1 minibatch: 293/600
# Época: 0/1 minibatch: 294/600
# Época: 0/1 minibatch: 295/600
# Época: 0/1 minibatch: 296/600
# Época: 0/1 minibatch: 297/600
# Época: 0/1 minibatch: 298/600
# Época: 0/1 minibatch: 299/600
# Época: 0/1 minibatch: 300/600
# Época: 0/1 minibatch: 301/600
# Época: 0/1 minibatch: 302/600
# Época: 0/1 minibatch: 303/600
# Época: 0/1 minibatch: 304/600
# Época: 0/1 minibatch: 305/600
# Época: 0/1 minibatch: 306/600
# Época: 0/1 minibatch: 307/600
# Época: 0/1 minibatch: 308/600
# Época: 0/1 minibatch: 309/600
# Época: 0/1 minibatch: 310/600
# Época: 0/1 minibatch: 311/600
# Época: 0/1 minibatch: 312/600
# Época: 0/1 minibatch: 313/600
# Época: 0/1 minibatch: 314/600
# Época: 0/1 minibatch: 315/600
# Época: 0/1 minibatch: 316/600
# Época: 0/1 minibatch: 317/600
# Época: 0/1 minibatch: 318/600
# Época: 0/1 minibatch: 319/600
# Época: 0/1 minibatch: 320/600
# Época: 0/1 minibatch: 321/600
# Época: 0/1 minibatch: 322/600
# Época: 0/1 minibatch: 323/600
# Época: 0/1 minibatch: 324/600
# Época: 0/1 minibatch: 325/600
# Época: 0/1 minibatch: 326/600
# Época: 0/1 minibatch: 327/600
# Época: 0/1 minibatch: 328/600
# Época: 0/1 minibatch: 329/600
# Época: 0/1 minibatch: 330/600
# Época: 0/1 minibatch: 331/600
# Época: 0/1 minibatch: 332/600
# Época: 0/1 minibatch: 333/600
# Época: 0/1 minibatch: 334/600
# Época: 0/1 minibatch: 335/600
# Época: 0/1 minibatch: 336/600
# Época: 0/1 minibatch: 337/600
# Época: 0/1 minibatch: 338/600
# Época: 0/1 minibatch: 339/600
# Época: 0/1 minibatch: 340/600
# Época: 0/1 minibatch: 341/600
# Época: 0/1 minibatch: 342/600
# Época: 0/1 minibatch: 343/600
# Época: 0/1 minibatch: 344/600
# Época: 0/1 minibatch: 345/600
# Época: 0/1 minibatch: 346/600
# Época: 0/1 minibatch: 347/600
# Época: 0/1 minibatch: 348/600
# Época: 0/1 minibatch: 349/600
# Época: 0/1 minibatch: 350/600
# Época: 0/1 minibatch: 351/600
# Época: 0/1 minibatch: 352/600
# Época: 0/1 minibatch: 353/600
# Época: 0/1 minibatch: 354/600
# Época: 0/1 minibatch: 355/600
# Época: 0/1 minibatch: 356/600
# Época: 0/1 minibatch: 357/600
# Época: 0/1 minibatch: 358/600
# Época: 0/1 minibatch: 359/600
# Época: 0/1 minibatch: 360/600
# Época: 0/1 minibatch: 361/600
# Época: 0/1 minibatch: 362/600
# Época: 0/1 minibatch: 363/600
# Época: 0/1 minibatch: 364/600
# Época: 0/1 minibatch: 365/600
# Época: 0/1 minibatch: 366/600
# Época: 0/1 minibatch: 367/600
# Época: 0/1 minibatch: 368/600
# Época: 0/1 minibatch: 369/600
# Época: 0/1 minibatch: 370/600
# Época: 0/1 minibatch: 371/600
# Época: 0/1 minibatch: 372/600
# Época: 0/1 minibatch: 373/600
# Época: 0/1 minibatch: 374/600
# Época: 0/1 minibatch: 375/600
# Época: 0/1 minibatch: 376/600
# Época: 0/1 minibatch: 377/600
# Época: 0/1 minibatch: 378/600
# Época: 0/1 minibatch: 379/600
# Época: 0/1 minibatch: 380/600
# Época: 0/1 minibatch: 381/600
# Época: 0/1 minibatch: 382/600
# Época: 0/1 minibatch: 383/600
# Época: 0/1 minibatch: 384/600
# Época: 0/1 minibatch: 385/600
# Época: 0/1 minibatch: 386/600
# Época: 0/1 minibatch: 387/600
# Época: 0/1 minibatch: 388/600
# Época: 0/1 minibatch: 389/600
# Época: 0/1 minibatch: 390/600
# Época: 0/1 minibatch: 391/600
# Época: 0/1 minibatch: 392/600
# Época: 0/1 minibatch: 393/600
# Época: 0/1 minibatch: 394/600
# Época: 0/1 minibatch: 395/600
# Época: 0/1 minibatch: 396/600
# Época: 0/1 minibatch: 397/600
# Época: 0/1 minibatch: 398/600
# Época: 0/1 minibatch: 399/600
# Época: 0/1 minibatch: 400/600
# Época: 0/1 minibatch: 401/600
# Época: 0/1 minibatch: 402/600
# Época: 0/1 minibatch: 403/600
# Época: 0/1 minibatch: 404/600
# Época: 0/1 minibatch: 405/600
# Época: 0/1 minibatch: 406/600
# Época: 0/1 minibatch: 407/600
# Época: 0/1 minibatch: 408/600
# Época: 0/1 minibatch: 409/600
# Época: 0/1 minibatch: 410/600
# Época: 0/1 minibatch: 411/600
# Época: 0/1 minibatch: 412/600
# Época: 0/1 minibatch: 413/600
# Época: 0/1 minibatch: 414/600
# Época: 0/1 minibatch: 415/600
# Época: 0/1 minibatch: 416/600
# Época: 0/1 minibatch: 417/600
# Época: 0/1 minibatch: 418/600
# Época: 0/1 minibatch: 419/600
# Época: 0/1 minibatch: 420/600
# Época: 0/1 minibatch: 421/600
# Época: 0/1 minibatch: 422/600
# Época: 0/1 minibatch: 423/600
# Época: 0/1 minibatch: 424/600
# Época: 0/1 minibatch: 425/600
# Época: 0/1 minibatch: 426/600
# Época: 0/1 minibatch: 427/600
# Época: 0/1 minibatch: 428/600
# Época: 0/1 minibatch: 429/600
# Época: 0/1 minibatch: 430/600
# Época: 0/1 minibatch: 431/600
# Época: 0/1 minibatch: 432/600
# Época: 0/1 minibatch: 433/600
# Época: 0/1 minibatch: 434/600
# Época: 0/1 minibatch: 435/600
# Época: 0/1 minibatch: 436/600
# Época: 0/1 minibatch: 437/600
# Época: 0/1 minibatch: 438/600
# Época: 0/1 minibatch: 439/600
# Época: 0/1 minibatch: 440/600
# Época: 0/1 minibatch: 441/600
# Época: 0/1 minibatch: 442/600
# Época: 0/1 minibatch: 443/600
# Época: 0/1 minibatch: 444/600
# Época: 0/1 minibatch: 445/600
# Época: 0/1 minibatch: 446/600
# Época: 0/1 minibatch: 447/600
# Época: 0/1 minibatch: 448/600
# Época: 0/1 minibatch: 449/600
# Época: 0/1 minibatch: 450/600
# Época: 0/1 minibatch: 451/600
# Época: 0/1 minibatch: 452/600
# Época: 0/1 minibatch: 453/600
# Época: 0/1 minibatch: 454/600
# Época: 0/1 minibatch: 455/600
# Época: 0/1 minibatch: 456/600
# Época: 0/1 minibatch: 457/600
# Época: 0/1 minibatch: 458/600
# Época: 0/1 minibatch: 459/600
# Época: 0/1 minibatch: 460/600
# Época: 0/1 minibatch: 461/600
# Época: 0/1 minibatch: 462/600
# Época: 0/1 minibatch: 463/600
# Época: 0/1 minibatch: 464/600
# Época: 0/1 minibatch: 465/600
# Época: 0/1 minibatch: 466/600
# Época: 0/1 minibatch: 467/600
# Época: 0/1 minibatch: 468/600
# Época: 0/1 minibatch: 469/600
# Época: 0/1 minibatch: 470/600
# Época: 0/1 minibatch: 471/600
# Época: 0/1 minibatch: 472/600
# Época: 0/1 minibatch: 473/600
# Época: 0/1 minibatch: 474/600
# Época: 0/1 minibatch: 475/600
# Época: 0/1 minibatch: 476/600
# Época: 0/1 minibatch: 477/600
# Época: 0/1 minibatch: 478/600
# Época: 0/1 minibatch: 479/600
# Época: 0/1 minibatch: 480/600
# Época: 0/1 minibatch: 481/600
# Época: 0/1 minibatch: 482/600
# Época: 0/1 minibatch: 483/600
# Época: 0/1 minibatch: 484/600
# Época: 0/1 minibatch: 485/600
# Época: 0/1 minibatch: 486/600
# Época: 0/1 minibatch: 487/600
# Época: 0/1 minibatch: 488/600
# Época: 0/1 minibatch: 489/600
# Época: 0/1 minibatch: 490/600
# Época: 0/1 minibatch: 491/600
# Época: 0/1 minibatch: 492/600
# Época: 0/1 minibatch: 493/600
# Época: 0/1 minibatch: 494/600
# Época: 0/1 minibatch: 495/600
# Época: 0/1 minibatch: 496/600
# Época: 0/1 minibatch: 497/600
# Época: 0/1 minibatch: 498/600
# Época: 0/1 minibatch: 499/600
# Época: 0/1 minibatch: 500/600
# Época: 0/1 minibatch: 501/600
# Época: 0/1 minibatch: 502/600
# Época: 0/1 minibatch: 503/600
# Época: 0/1 minibatch: 504/600
# Época: 0/1 minibatch: 505/600
# Época: 0/1 minibatch: 506/600
# Época: 0/1 minibatch: 507/600
# Época: 0/1 minibatch: 508/600
# Época: 0/1 minibatch: 509/600
# Época: 0/1 minibatch: 510/600
# Época: 0/1 minibatch: 511/600
# Época: 0/1 minibatch: 512/600
# Época: 0/1 minibatch: 513/600
# Época: 0/1 minibatch: 514/600
# Época: 0/1 minibatch: 515/600
# Época: 0/1 minibatch: 516/600
# Época: 0/1 minibatch: 517/600
# Época: 0/1 minibatch: 518/600
# Época: 0/1 minibatch: 519/600
# Época: 0/1 minibatch: 520/600
# Época: 0/1 minibatch: 521/600
# Época: 0/1 minibatch: 522/600
# Época: 0/1 minibatch: 523/600
# Época: 0/1 minibatch: 524/600
# Época: 0/1 minibatch: 525/600
# Época: 0/1 minibatch: 526/600
# Época: 0/1 minibatch: 527/600
# Época: 0/1 minibatch: 528/600
# Época: 0/1 minibatch: 529/600
# Época: 0/1 minibatch: 530/600
# Época: 0/1 minibatch: 531/600
# Época: 0/1 minibatch: 532/600
# Época: 0/1 minibatch: 533/600
# Época: 0/1 minibatch: 534/600
# Época: 0/1 minibatch: 535/600
# Época: 0/1 minibatch: 536/600
# Época: 0/1 minibatch: 537/600
# Época: 0/1 minibatch: 538/600
# Época: 0/1 minibatch: 539/600
# Época: 0/1 minibatch: 540/600
# Época: 0/1 minibatch: 541/600
# Época: 0/1 minibatch: 542/600
# Época: 0/1 minibatch: 543/600
# Época: 0/1 minibatch: 544/600
# Época: 0/1 minibatch: 545/600
# Época: 0/1 minibatch: 546/600
# Época: 0/1 minibatch: 547/600
# Época: 0/1 minibatch: 548/600
# Época: 0/1 minibatch: 549/600
# Época: 0/1 minibatch: 550/600
# Época: 0/1 minibatch: 551/600
# Época: 0/1 minibatch: 552/600
# Época: 0/1 minibatch: 553/600
# Época: 0/1 minibatch: 554/600
# Época: 0/1 minibatch: 555/600
# Época: 0/1 minibatch: 556/600
# Época: 0/1 minibatch: 557/600
# Época: 0/1 minibatch: 558/600
# Época: 0/1 minibatch: 559/600
# Época: 0/1 minibatch: 560/600
# Época: 0/1 minibatch: 561/600
# Época: 0/1 minibatch: 562/600
# Época: 0/1 minibatch: 563/600
# Época: 0/1 minibatch: 564/600
# Época: 0/1 minibatch: 565/600
# Época: 0/1 minibatch: 566/600
# Época: 0/1 minibatch: 567/600
# Época: 0/1 minibatch: 568/600
# Época: 0/1 minibatch: 569/600
# Época: 0/1 minibatch: 570/600
# Época: 0/1 minibatch: 571/600
# Época: 0/1 minibatch: 572/600
# Época: 0/1 minibatch: 573/600
# Época: 0/1 minibatch: 574/600
# Época: 0/1 minibatch: 575/600
# Época: 0/1 minibatch: 576/600
# Época: 0/1 minibatch: 577/600
# Época: 0/1 minibatch: 578/600
# Época: 0/1 minibatch: 579/600
# Época: 0/1 minibatch: 580/600
# Época: 0/1 minibatch: 581/600
# Época: 0/1 minibatch: 582/600
# Época: 0/1 minibatch: 583/600
# Época: 0/1 minibatch: 584/600
# Época: 0/1 minibatch: 585/600
# Época: 0/1 minibatch: 586/600
# Época: 0/1 minibatch: 587/600
# Época: 0/1 minibatch: 588/600
# Época: 0/1 minibatch: 589/600
# Época: 0/1 minibatch: 590/600
# Época: 0/1 minibatch: 591/600
# Época: 0/1 minibatch: 592/600
# Época: 0/1 minibatch: 593/600
# Época: 0/1 minibatch: 594/600
# Época: 0/1 minibatch: 595/600
# Época: 0/1 minibatch: 596/600
# Época: 0/1 minibatch: 597/600
# Época: 0/1 minibatch: 598/600
# Época: 0/1 minibatch: 599/600
# Época: 0/1 minibatch: 600/600
# Época: 1/1 minibatch: 1/600
# Época: 1/1 minibatch: 2/600
# Época: 1/1 minibatch: 3/600
# Época: 1/1 minibatch: 4/600
# Época: 1/1 minibatch: 5/600
# Época: 1/1 minibatch: 6/600
# Época: 1/1 minibatch: 7/600
# Época: 1/1 minibatch: 8/600
# Época: 1/1 minibatch: 9/600
# Época: 1/1 minibatch: 10/600
# Época: 1/1 minibatch: 11/600
# Época: 1/1 minibatch: 12/600
# Época: 1/1 minibatch: 13/600
# Época: 1/1 minibatch: 14/600
# Época: 1/1 minibatch: 15/600
# Época: 1/1 minibatch: 16/600
# Época: 1/1 minibatch: 17/600
# Época: 1/1 minibatch: 18/600
# Época: 1/1 minibatch: 19/600
# Época: 1/1 minibatch: 20/600
# Época: 1/1 minibatch: 21/600
# Época: 1/1 minibatch: 22/600
# Época: 1/1 minibatch: 23/600
# Época: 1/1 minibatch: 24/600
# Época: 1/1 minibatch: 25/600
# Época: 1/1 minibatch: 26/600
# Época: 1/1 minibatch: 27/600
# Época: 1/1 minibatch: 28/600
# Época: 1/1 minibatch: 29/600
# Época: 1/1 minibatch: 30/600
# Época: 1/1 minibatch: 31/600
# Época: 1/1 minibatch: 32/600
# Época: 1/1 minibatch: 33/600
# Época: 1/1 minibatch: 34/600
# Época: 1/1 minibatch: 35/600
# Época: 1/1 minibatch: 36/600
# Época: 1/1 minibatch: 37/600
# Época: 1/1 minibatch: 38/600
# Época: 1/1 minibatch: 39/600
# Época: 1/1 minibatch: 40/600
# Época: 1/1 minibatch: 41/600
# Época: 1/1 minibatch: 42/600
# Época: 1/1 minibatch: 43/600
# Época: 1/1 minibatch: 44/600
# Época: 1/1 minibatch: 45/600
# Época: 1/1 minibatch: 46/600
# Época: 1/1 minibatch: 47/600
# Época: 1/1 minibatch: 48/600
# Época: 1/1 minibatch: 49/600
# Época: 1/1 minibatch: 50/600
# Época: 1/1 minibatch: 51/600
# Época: 1/1 minibatch: 52/600
# Época: 1/1 minibatch: 53/600
# Época: 1/1 minibatch: 54/600
# Época: 1/1 minibatch: 55/600
# Época: 1/1 minibatch: 56/600
# Época: 1/1 minibatch: 57/600
# Época: 1/1 minibatch: 58/600
# Época: 1/1 minibatch: 59/600
# Época: 1/1 minibatch: 60/600
# Época: 1/1 minibatch: 61/600
# Época: 1/1 minibatch: 62/600
# Época: 1/1 minibatch: 63/600
# Época: 1/1 minibatch: 64/600
# Época: 1/1 minibatch: 65/600
# Época: 1/1 minibatch: 66/600
# Época: 1/1 minibatch: 67/600
# Época: 1/1 minibatch: 68/600
# Época: 1/1 minibatch: 69/600
# Época: 1/1 minibatch: 70/600
# Época: 1/1 minibatch: 71/600
# Época: 1/1 minibatch: 72/600
# Época: 1/1 minibatch: 73/600
# Época: 1/1 minibatch: 74/600
# Época: 1/1 minibatch: 75/600
# Época: 1/1 minibatch: 76/600
# Época: 1/1 minibatch: 77/600
# Época: 1/1 minibatch: 78/600
# Época: 1/1 minibatch: 79/600
# Época: 1/1 minibatch: 80/600
# Época: 1/1 minibatch: 81/600
# Época: 1/1 minibatch: 82/600
# Época: 1/1 minibatch: 83/600
# Época: 1/1 minibatch: 84/600
# Época: 1/1 minibatch: 85/600
# Época: 1/1 minibatch: 86/600
# Época: 1/1 minibatch: 87/600
# Época: 1/1 minibatch: 88/600
# Época: 1/1 minibatch: 89/600
# Época: 1/1 minibatch: 90/600
# Época: 1/1 minibatch: 91/600
# Época: 1/1 minibatch: 92/600
# Época: 1/1 minibatch: 93/600
# Época: 1/1 minibatch: 94/600
# Época: 1/1 minibatch: 95/600
# Época: 1/1 minibatch: 96/600
# Época: 1/1 minibatch: 97/600
# Época: 1/1 minibatch: 98/600
# Época: 1/1 minibatch: 99/600
# Época: 1/1 minibatch: 100/600
# Época: 1/1 minibatch: 101/600
# Época: 1/1 minibatch: 102/600
# Época: 1/1 minibatch: 103/600
# Época: 1/1 minibatch: 104/600
# Época: 1/1 minibatch: 105/600
# Época: 1/1 minibatch: 106/600
# Época: 1/1 minibatch: 107/600
# Época: 1/1 minibatch: 108/600
# Época: 1/1 minibatch: 109/600
# Época: 1/1 minibatch: 110/600
# Época: 1/1 minibatch: 111/600
# Época: 1/1 minibatch: 112/600
# Época: 1/1 minibatch: 113/600
# Época: 1/1 minibatch: 114/600
# Época: 1/1 minibatch: 115/600
# Época: 1/1 minibatch: 116/600
# Época: 1/1 minibatch: 117/600
# Época: 1/1 minibatch: 118/600
# Época: 1/1 minibatch: 119/600
# Época: 1/1 minibatch: 120/600
# Época: 1/1 minibatch: 121/600
# Época: 1/1 minibatch: 122/600
# Época: 1/1 minibatch: 123/600
# Época: 1/1 minibatch: 124/600
# Época: 1/1 minibatch: 125/600
# Época: 1/1 minibatch: 126/600
# Época: 1/1 minibatch: 127/600
# Época: 1/1 minibatch: 128/600
# Época: 1/1 minibatch: 129/600
# Época: 1/1 minibatch: 130/600
# Época: 1/1 minibatch: 131/600
# Época: 1/1 minibatch: 132/600
# Época: 1/1 minibatch: 133/600
# Época: 1/1 minibatch: 134/600
# Época: 1/1 minibatch: 135/600
# Época: 1/1 minibatch: 136/600
# Época: 1/1 minibatch: 137/600
# Época: 1/1 minibatch: 138/600
# Época: 1/1 minibatch: 139/600
# Época: 1/1 minibatch: 140/600
# Época: 1/1 minibatch: 141/600
# Época: 1/1 minibatch: 142/600
# Época: 1/1 minibatch: 143/600
# Época: 1/1 minibatch: 144/600
# Época: 1/1 minibatch: 145/600
# Época: 1/1 minibatch: 146/600
# Época: 1/1 minibatch: 147/600
# Época: 1/1 minibatch: 148/600
# Época: 1/1 minibatch: 149/600
# Época: 1/1 minibatch: 150/600
# Época: 1/1 minibatch: 151/600
# Época: 1/1 minibatch: 152/600
# Época: 1/1 minibatch: 153/600
# Época: 1/1 minibatch: 154/600
# Época: 1/1 minibatch: 155/600
# Época: 1/1 minibatch: 156/600
# Época: 1/1 minibatch: 157/600
# Época: 1/1 minibatch: 158/600
# Época: 1/1 minibatch: 159/600
# Época: 1/1 minibatch: 160/600
# Época: 1/1 minibatch: 161/600
# Época: 1/1 minibatch: 162/600
# Época: 1/1 minibatch: 163/600
# Época: 1/1 minibatch: 164/600
# Época: 1/1 minibatch: 165/600
# Época: 1/1 minibatch: 166/600
# Época: 1/1 minibatch: 167/600
# Época: 1/1 minibatch: 168/600
# Época: 1/1 minibatch: 169/600
# Época: 1/1 minibatch: 170/600
# Época: 1/1 minibatch: 171/600
# Época: 1/1 minibatch: 172/600
# Época: 1/1 minibatch: 173/600
# Época: 1/1 minibatch: 174/600
# Época: 1/1 minibatch: 175/600
# Época: 1/1 minibatch: 176/600
# Época: 1/1 minibatch: 177/600
# Época: 1/1 minibatch: 178/600
# Época: 1/1 minibatch: 179/600
# Época: 1/1 minibatch: 180/600
# Época: 1/1 minibatch: 181/600
# Época: 1/1 minibatch: 182/600
# Época: 1/1 minibatch: 183/600
# Época: 1/1 minibatch: 184/600
# Época: 1/1 minibatch: 185/600
# Época: 1/1 minibatch: 186/600
# Época: 1/1 minibatch: 187/600
# Época: 1/1 minibatch: 188/600
# Época: 1/1 minibatch: 189/600
# Época: 1/1 minibatch: 190/600
# Época: 1/1 minibatch: 191/600
# Época: 1/1 minibatch: 192/600
# Época: 1/1 minibatch: 193/600
# Época: 1/1 minibatch: 194/600
# Época: 1/1 minibatch: 195/600
# Época: 1/1 minibatch: 196/600
# Época: 1/1 minibatch: 197/600
# Época: 1/1 minibatch: 198/600
# Época: 1/1 minibatch: 199/600
# Época: 1/1 minibatch: 200/600
# Época: 1/1 minibatch: 201/600
# Época: 1/1 minibatch: 202/600
# Época: 1/1 minibatch: 203/600
# Época: 1/1 minibatch: 204/600
# Época: 1/1 minibatch: 205/600
# Época: 1/1 minibatch: 206/600
# Época: 1/1 minibatch: 207/600
# Época: 1/1 minibatch: 208/600
# Época: 1/1 minibatch: 209/600
# Época: 1/1 minibatch: 210/600
# Época: 1/1 minibatch: 211/600
# Época: 1/1 minibatch: 212/600
# Época: 1/1 minibatch: 213/600
# Época: 1/1 minibatch: 214/600
# Época: 1/1 minibatch: 215/600
# Época: 1/1 minibatch: 216/600
# Época: 1/1 minibatch: 217/600
# Época: 1/1 minibatch: 218/600
# Época: 1/1 minibatch: 219/600
# Época: 1/1 minibatch: 220/600
# Época: 1/1 minibatch: 221/600
# Época: 1/1 minibatch: 222/600
# Época: 1/1 minibatch: 223/600
# Época: 1/1 minibatch: 224/600
# Época: 1/1 minibatch: 225/600
# Época: 1/1 minibatch: 226/600
# Época: 1/1 minibatch: 227/600
# Época: 1/1 minibatch: 228/600
# Época: 1/1 minibatch: 229/600
# Época: 1/1 minibatch: 230/600
# Época: 1/1 minibatch: 231/600
# Época: 1/1 minibatch: 232/600
# Época: 1/1 minibatch: 233/600
# Época: 1/1 minibatch: 234/600
# Época: 1/1 minibatch: 235/600
# Época: 1/1 minibatch: 236/600
# Época: 1/1 minibatch: 237/600
# Época: 1/1 minibatch: 238/600
# Época: 1/1 minibatch: 239/600
# Época: 1/1 minibatch: 240/600
# Época: 1/1 minibatch: 241/600
# Época: 1/1 minibatch: 242/600
# Época: 1/1 minibatch: 243/600
# Época: 1/1 minibatch: 244/600
# Época: 1/1 minibatch: 245/600
# Época: 1/1 minibatch: 246/600
# Época: 1/1 minibatch: 247/600
# Época: 1/1 minibatch: 248/600
# Época: 1/1 minibatch: 249/600
# Época: 1/1 minibatch: 250/600
# Época: 1/1 minibatch: 251/600
# Época: 1/1 minibatch: 252/600
# Época: 1/1 minibatch: 253/600
# Época: 1/1 minibatch: 254/600
# Época: 1/1 minibatch: 255/600
# Época: 1/1 minibatch: 256/600
# Época: 1/1 minibatch: 257/600
# Época: 1/1 minibatch: 258/600
# Época: 1/1 minibatch: 259/600
# Época: 1/1 minibatch: 260/600
# Época: 1/1 minibatch: 261/600
# Época: 1/1 minibatch: 262/600
# Época: 1/1 minibatch: 263/600
# Época: 1/1 minibatch: 264/600
# Época: 1/1 minibatch: 265/600
# Época: 1/1 minibatch: 266/600
# Época: 1/1 minibatch: 267/600
# Época: 1/1 minibatch: 268/600
# Época: 1/1 minibatch: 269/600
# Época: 1/1 minibatch: 270/600
# Época: 1/1 minibatch: 271/600
# Época: 1/1 minibatch: 272/600
# Época: 1/1 minibatch: 273/600
# Época: 1/1 minibatch: 274/600
# Época: 1/1 minibatch: 275/600
# Época: 1/1 minibatch: 276/600
# Época: 1/1 minibatch: 277/600
# Época: 1/1 minibatch: 278/600
# Época: 1/1 minibatch: 279/600
# Época: 1/1 minibatch: 280/600
# Época: 1/1 minibatch: 281/600
# Época: 1/1 minibatch: 282/600
# Época: 1/1 minibatch: 283/600
# Época: 1/1 minibatch: 284/600
# Época: 1/1 minibatch: 285/600
# Época: 1/1 minibatch: 286/600
# Época: 1/1 minibatch: 287/600
# Época: 1/1 minibatch: 288/600
# Época: 1/1 minibatch: 289/600
# Época: 1/1 minibatch: 290/600
# Época: 1/1 minibatch: 291/600
# Época: 1/1 minibatch: 292/600
# Época: 1/1 minibatch: 293/600
# Época: 1/1 minibatch: 294/600
# Época: 1/1 minibatch: 295/600
# Época: 1/1 minibatch: 296/600
# Época: 1/1 minibatch: 297/600
# Época: 1/1 minibatch: 298/600
# Época: 1/1 minibatch: 299/600
# Época: 1/1 minibatch: 300/600
# Época: 1/1 minibatch: 301/600
# Época: 1/1 minibatch: 302/600
# Época: 1/1 minibatch: 303/600
# Época: 1/1 minibatch: 304/600
# Época: 1/1 minibatch: 305/600
# Época: 1/1 minibatch: 306/600
# Época: 1/1 minibatch: 307/600
# Época: 1/1 minibatch: 308/600
# Época: 1/1 minibatch: 309/600
# Época: 1/1 minibatch: 310/600
# Época: 1/1 minibatch: 311/600
# Época: 1/1 minibatch: 312/600
# Época: 1/1 minibatch: 313/600
# Época: 1/1 minibatch: 314/600
# Época: 1/1 minibatch: 315/600
# Época: 1/1 minibatch: 316/600
# Época: 1/1 minibatch: 317/600
# Época: 1/1 minibatch: 318/600
# Época: 1/1 minibatch: 319/600
# Época: 1/1 minibatch: 320/600
# Época: 1/1 minibatch: 321/600
# Época: 1/1 minibatch: 322/600
# Época: 1/1 minibatch: 323/600
# Época: 1/1 minibatch: 324/600
# Época: 1/1 minibatch: 325/600
# Época: 1/1 minibatch: 326/600
# Época: 1/1 minibatch: 327/600
# Época: 1/1 minibatch: 328/600
# Época: 1/1 minibatch: 329/600
# Época: 1/1 minibatch: 330/600
# Época: 1/1 minibatch: 331/600
# Época: 1/1 minibatch: 332/600
# Época: 1/1 minibatch: 333/600
# Época: 1/1 minibatch: 334/600
# Época: 1/1 minibatch: 335/600
# Época: 1/1 minibatch: 336/600
# Época: 1/1 minibatch: 337/600
# Época: 1/1 minibatch: 338/600
# Época: 1/1 minibatch: 339/600
# Época: 1/1 minibatch: 340/600
# Época: 1/1 minibatch: 341/600
# Época: 1/1 minibatch: 342/600
# Época: 1/1 minibatch: 343/600
# Época: 1/1 minibatch: 344/600
# Época: 1/1 minibatch: 345/600
# Época: 1/1 minibatch: 346/600
# Época: 1/1 minibatch: 347/600
# Época: 1/1 minibatch: 348/600
# Época: 1/1 minibatch: 349/600
# Época: 1/1 minibatch: 350/600
# Época: 1/1 minibatch: 351/600
# Época: 1/1 minibatch: 352/600
# Época: 1/1 minibatch: 353/600
# Época: 1/1 minibatch: 354/600
# Época: 1/1 minibatch: 355/600
# Época: 1/1 minibatch: 356/600
# Época: 1/1 minibatch: 357/600
# Época: 1/1 minibatch: 358/600
# Época: 1/1 minibatch: 359/600
# Época: 1/1 minibatch: 360/600
# Época: 1/1 minibatch: 361/600
# Época: 1/1 minibatch: 362/600
# Época: 1/1 minibatch: 363/600
# Época: 1/1 minibatch: 364/600
# Época: 1/1 minibatch: 365/600
# Época: 1/1 minibatch: 366/600
# Época: 1/1 minibatch: 367/600
# Época: 1/1 minibatch: 368/600
# Época: 1/1 minibatch: 369/600
# Época: 1/1 minibatch: 370/600
# Época: 1/1 minibatch: 371/600
# Época: 1/1 minibatch: 372/600
# Época: 1/1 minibatch: 373/600
# Época: 1/1 minibatch: 374/600
# Época: 1/1 minibatch: 375/600
# Época: 1/1 minibatch: 376/600
# Época: 1/1 minibatch: 377/600
# Época: 1/1 minibatch: 378/600
# Época: 1/1 minibatch: 379/600
# Época: 1/1 minibatch: 380/600
# Época: 1/1 minibatch: 381/600
# Época: 1/1 minibatch: 382/600
# Época: 1/1 minibatch: 383/600
# Época: 1/1 minibatch: 384/600
# Época: 1/1 minibatch: 385/600
# Época: 1/1 minibatch: 386/600
# Época: 1/1 minibatch: 387/600
# Época: 1/1 minibatch: 388/600
# Época: 1/1 minibatch: 389/600
# Época: 1/1 minibatch: 390/600
# Época: 1/1 minibatch: 391/600
# Época: 1/1 minibatch: 392/600
# Época: 1/1 minibatch: 393/600
# Época: 1/1 minibatch: 394/600
# Época: 1/1 minibatch: 395/600
# Época: 1/1 minibatch: 396/600
# Época: 1/1 minibatch: 397/600
# Época: 1/1 minibatch: 398/600
# Época: 1/1 minibatch: 399/600
# Época: 1/1 minibatch: 400/600
# Época: 1/1 minibatch: 401/600
# Época: 1/1 minibatch: 402/600
# Época: 1/1 minibatch: 403/600
# Época: 1/1 minibatch: 404/600
# Época: 1/1 minibatch: 405/600
# Época: 1/1 minibatch: 406/600
# Época: 1/1 minibatch: 407/600
# Época: 1/1 minibatch: 408/600
# Época: 1/1 minibatch: 409/600
# Época: 1/1 minibatch: 410/600
# Época: 1/1 minibatch: 411/600
# Época: 1/1 minibatch: 412/600
# Época: 1/1 minibatch: 413/600
# Época: 1/1 minibatch: 414/600
# Época: 1/1 minibatch: 415/600
# Época: 1/1 minibatch: 416/600
# Época: 1/1 minibatch: 417/600
# Época: 1/1 minibatch: 418/600
# Época: 1/1 minibatch: 419/600
# Época: 1/1 minibatch: 420/600
# Época: 1/1 minibatch: 421/600
# Época: 1/1 minibatch: 422/600
# Época: 1/1 minibatch: 423/600
# Época: 1/1 minibatch: 424/600
# Época: 1/1 minibatch: 425/600
# Época: 1/1 minibatch: 426/600
# Época: 1/1 minibatch: 427/600
# Época: 1/1 minibatch: 428/600
# Época: 1/1 minibatch: 429/600
# Época: 1/1 minibatch: 430/600
# Época: 1/1 minibatch: 431/600
# Época: 1/1 minibatch: 432/600
# Época: 1/1 minibatch: 433/600
# Época: 1/1 minibatch: 434/600
# Época: 1/1 minibatch: 435/600
# Época: 1/1 minibatch: 436/600
# Época: 1/1 minibatch: 437/600
# Época: 1/1 minibatch: 438/600
# Época: 1/1 minibatch: 439/600
# Época: 1/1 minibatch: 440/600
# Época: 1/1 minibatch: 441/600
# Época: 1/1 minibatch: 442/600
# Época: 1/1 minibatch: 443/600
# Época: 1/1 minibatch: 444/600
# Época: 1/1 minibatch: 445/600
# Época: 1/1 minibatch: 446/600
# Época: 1/1 minibatch: 447/600
# Época: 1/1 minibatch: 448/600
# Época: 1/1 minibatch: 449/600
# Época: 1/1 minibatch: 450/600
# Época: 1/1 minibatch: 451/600
# Época: 1/1 minibatch: 452/600
# Época: 1/1 minibatch: 453/600
# Época: 1/1 minibatch: 454/600
# Época: 1/1 minibatch: 455/600
# Época: 1/1 minibatch: 456/600
# Época: 1/1 minibatch: 457/600
# Época: 1/1 minibatch: 458/600
# Época: 1/1 minibatch: 459/600
# Época: 1/1 minibatch: 460/600
# Época: 1/1 minibatch: 461/600
# Época: 1/1 minibatch: 462/600
# Época: 1/1 minibatch: 463/600
# Época: 1/1 minibatch: 464/600
# Época: 1/1 minibatch: 465/600
# Época: 1/1 minibatch: 466/600
# Época: 1/1 minibatch: 467/600
# Época: 1/1 minibatch: 468/600
# Época: 1/1 minibatch: 469/600
# Época: 1/1 minibatch: 470/600
# Época: 1/1 minibatch: 471/600
# Época: 1/1 minibatch: 472/600
# Época: 1/1 minibatch: 473/600
# Época: 1/1 minibatch: 474/600
# Época: 1/1 minibatch: 475/600
# Época: 1/1 minibatch: 476/600
# Época: 1/1 minibatch: 477/600
# Época: 1/1 minibatch: 478/600
# Época: 1/1 minibatch: 479/600
# Época: 1/1 minibatch: 480/600
# Época: 1/1 minibatch: 481/600
# Época: 1/1 minibatch: 482/600
# Época: 1/1 minibatch: 483/600
# Época: 1/1 minibatch: 484/600
# Época: 1/1 minibatch: 485/600
# Época: 1/1 minibatch: 486/600
# Época: 1/1 minibatch: 487/600
# Época: 1/1 minibatch: 488/600
# Época: 1/1 minibatch: 489/600
# Época: 1/1 minibatch: 490/600
# Época: 1/1 minibatch: 491/600
# Época: 1/1 minibatch: 492/600
# Época: 1/1 minibatch: 493/600
# Época: 1/1 minibatch: 494/600
# Época: 1/1 minibatch: 495/600
# Época: 1/1 minibatch: 496/600
# Época: 1/1 minibatch: 497/600
# Época: 1/1 minibatch: 498/600
# Época: 1/1 minibatch: 499/600
# Época: 1/1 minibatch: 500/600
# Época: 1/1 minibatch: 501/600
# Época: 1/1 minibatch: 502/600
# Época: 1/1 minibatch: 503/600
# Época: 1/1 minibatch: 504/600
# Época: 1/1 minibatch: 505/600
# Época: 1/1 minibatch: 506/600
# Época: 1/1 minibatch: 507/600
# Época: 1/1 minibatch: 508/600
# Época: 1/1 minibatch: 509/600
# Época: 1/1 minibatch: 510/600
# Época: 1/1 minibatch: 511/600
# Época: 1/1 minibatch: 512/600
# Época: 1/1 minibatch: 513/600
# Época: 1/1 minibatch: 514/600
# Época: 1/1 minibatch: 515/600
# Época: 1/1 minibatch: 516/600
# Época: 1/1 minibatch: 517/600
# Época: 1/1 minibatch: 518/600
# Época: 1/1 minibatch: 519/600
# Época: 1/1 minibatch: 520/600
# Época: 1/1 minibatch: 521/600
# Época: 1/1 minibatch: 522/600
# Época: 1/1 minibatch: 523/600
# Época: 1/1 minibatch: 524/600
# Época: 1/1 minibatch: 525/600
# Época: 1/1 minibatch: 526/600
# Época: 1/1 minibatch: 527/600
# Época: 1/1 minibatch: 528/600
# Época: 1/1 minibatch: 529/600
# Época: 1/1 minibatch: 530/600
# Época: 1/1 minibatch: 531/600
# Época: 1/1 minibatch: 532/600
# Época: 1/1 minibatch: 533/600
# Época: 1/1 minibatch: 534/600
# Época: 1/1 minibatch: 535/600
# Época: 1/1 minibatch: 536/600
# Época: 1/1 minibatch: 537/600
# Época: 1/1 minibatch: 538/600
# Época: 1/1 minibatch: 539/600
# Época: 1/1 minibatch: 540/600
# Época: 1/1 minibatch: 541/600
# Época: 1/1 minibatch: 542/600
# Época: 1/1 minibatch: 543/600
# Época: 1/1 minibatch: 544/600
# Época: 1/1 minibatch: 545/600
# Época: 1/1 minibatch: 546/600
# Época: 1/1 minibatch: 547/600
# Época: 1/1 minibatch: 548/600
# Época: 1/1 minibatch: 549/600
# Época: 1/1 minibatch: 550/600
# Época: 1/1 minibatch: 551/600
# Época: 1/1 minibatch: 552/600
# Época: 1/1 minibatch: 553/600
# Época: 1/1 minibatch: 554/600
# Época: 1/1 minibatch: 555/600
# Época: 1/1 minibatch: 556/600
# Época: 1/1 minibatch: 557/600
# Época: 1/1 minibatch: 558/600
# Época: 1/1 minibatch: 559/600
# Época: 1/1 minibatch: 560/600
# Época: 1/1 minibatch: 561/600
# Época: 1/1 minibatch: 562/600
# Época: 1/1 minibatch: 563/600
# Época: 1/1 minibatch: 564/600
# Época: 1/1 minibatch: 565/600
# Época: 1/1 minibatch: 566/600
# Época: 1/1 minibatch: 567/600
# Época: 1/1 minibatch: 568/600
# Época: 1/1 minibatch: 569/600
# Época: 1/1 minibatch: 570/600
# Época: 1/1 minibatch: 571/600
# Época: 1/1 minibatch: 572/600
# Época: 1/1 minibatch: 573/600
# Época: 1/1 minibatch: 574/600
# Época: 1/1 minibatch: 575/600
# Época: 1/1 minibatch: 576/600
# Época: 1/1 minibatch: 577/600
# Época: 1/1 minibatch: 578/600
# Época: 1/1 minibatch: 579/600
# Época: 1/1 minibatch: 580/600
# Época: 1/1 minibatch: 581/600
# Época: 1/1 minibatch: 582/600
# Época: 1/1 minibatch: 583/600
# Época: 1/1 minibatch: 584/600
# Época: 1/1 minibatch: 585/600
# Época: 1/1 minibatch: 586/600
# Época: 1/1 minibatch: 587/600
# Época: 1/1 minibatch: 588/600
# Época: 1/1 minibatch: 589/600
# Época: 1/1 minibatch: 590/600
# Época: 1/1 minibatch: 591/600
# Época: 1/1 minibatch: 592/600
# Época: 1/1 minibatch: 593/600
# Época: 1/1 minibatch: 594/600
# Época: 1/1 minibatch: 595/600
# Época: 1/1 minibatch: 596/600
# Época: 1/1 minibatch: 597/600
# Época: 1/1 minibatch: 598/600
# Época: 1/1 minibatch: 599/600
# Época: 1/1 minibatch: 600/600

# %%
print('Final loss:', loss.data)
# Out:
# Final loss: tensor(0.2920)

# %% [markdown]
# ### Visualizando gráfico de perda durante o treinamento

# %%
plt.plot(epochs, losses)
plt.xlabel('época')
# Out:
# Text(0.5, 0, 'época')

# %% [markdown]
# ### Visualização usual da perda, somente no final de cada minibatch

# %%
plt.plot(epochs[:5 * n_batches_train +1:n_batches_train], losses[:5 * n_batches_train+1:n_batches_train])
plt.xlabel('época')
# Out:
# Text(0.5, 0, 'época')

# %% [markdown]
# # Atividades

# %% [markdown]
# ## Perguntas

# %% [markdown]
# 1. Qual é o tamanho do mini-batch?
# 2. Em uma época, quantos mini-batches existem?
# 3. Qual é a definição de época?

# %% [markdown]
# ## Exercícios

# %% [markdown]
# 1. Coloque um print no final de cada minibatch, no mesmo estilo do print do final de época, no seguinte estilo:
#     - Época: 1/4, batch: 3/10
# 2. Altere o tamanho de minibatch (batch_size) algumas vezes, refaça o treinamento, e compare no gráfico abaixo a queda da perda para cada tamanho de minibatch.

# %% [markdown]
# ## Conclusões sobre os experimentos deste notebook

# %% [markdown]
# 1. O mini-batch contribui com a rapidez da convergência, num mesmo número de épocas
# 2. Os resultado pode ser mais ruidoso
